# %% [markdown]
# # Retail Analytics – Data Exploration
#
# ## Objective
# Explore the retail sales_orders dataset to understand schema, volume, and data quality
# before designing Bronze ingestion pipelines.

# %%
dbutils.fs.ls("/databricks-datasets/retail-org/sales_orders")

# %%
sales_orders_df = (
    spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .csv("/databricks-datasets/retail-org/sales_orders")
)

display(sales_orders_df.limit(10))
