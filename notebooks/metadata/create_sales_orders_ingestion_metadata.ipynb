# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.metadata;

CREATE TABLE IF NOT EXISTS workspace.metadata.sales_orders_file_audit (
    file_path STRING,
    ingestion_time TIMESTAMP,
    status STRING
)
USING DELTA;
